# %%
pip install opencv-python pillow numpy scikit-learn tensorflow torch torchvision scikit-image

# %%
pip install scikit-image
# Out:
# Collecting scikit-image
#   Downloading scikit_image-0.23.2-cp312-cp312-macosx_12_0_arm64.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.23 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from scikit-image) (1.26.4)
# Requirement already satisfied: scipy>=1.9 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from scikit-image) (1.13.1)
# Requirement already satisfied: networkx>=2.8 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from scikit-image) (3.3)
# Requirement already satisfied: pillow>=9.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from scikit-image) (10.3.0)
# Collecting imageio>=2.33 (from scikit-image)
#   Downloading imageio-2.34.1-py3-none-any.whl.metadata (4.9 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image)
#   Downloading tifffile-2024.5.22-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: packaging>=21 in /Users/siddikkhan/Library/Python/3.12/lib/python/site-packages (from scikit-image) (24.0)
# Collecting lazy-loader>=0.4 (from scikit-image)
#   Downloading lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Downloading scikit_image-0.23.2-cp312-cp312-macosx_12_0_arm64.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 2.1 MB/s eta 0:00:0000:0100:01
# Downloading imageio-2.34.1-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.5/313.5 kB 5.9 MB/s eta 0:00:00 0:00:01
# Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Downloading tifffile-2024.5.22-py3-none-any.whl (225 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.5/225.5 kB 6.6 MB/s eta 0:00:00
# Installing collected packages: tifffile, lazy-loader, imageio, scikit-image
# Successfully installed imageio-2.34.1 lazy-loader-0.4 scikit-image-0.23.2 tifffile-2024.5.22
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras import layers, models
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from PIL import Image
from skimage.metrics import peak_signal_noise_ratio as psnr
import matplotlib.pyplot as plt

# %%
import os
import cv2

def load_images_from_directory(directory, image_size=(128, 128)):
    image_list = []
    files = [f for f in os.listdir(directory) if os.path.isfile(os.path.join(directory, f))]
    
    for file in files:
        path_to_image = os.path.join(directory, file)
        image = cv2.imread(path_to_image)
        if image is None:
            continue
        
        # Process the image
        rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        resized_image = cv2.resize(rgb_image, image_size)
        normalized_image = resized_image.astype('float32') / 255.0
        
        image_list.append(normalized_image)
    
    return image_list

# %%
low_folder_path = '/Users/siddikkhan/Downloads/Train/low'
high_folder_path = '/Users/siddikkhan/Downloads/Train/high'
desired_image_size = (128, 128)  # Target image dimensions

noisy_images = load_images_from_directory(low_folder_path, desired_image_size)
clean_images = load_images_from_directory(high_folder_path, desired_image_size)

# %%
train_noisy, test_noisy, train_clean, test_clean = train_test_split(
    noisy_images, clean_images, test_size=0.2, random_state=42
)

# %%
def preprocess_image(image):
    return tf.image.convert_image_dtype(image, tf.float32)

# Define batch size
batch_size = 32

# Create TensorFlow datasets
train_ds = tf.data.Dataset.from_tensor_slices((train_noisy, train_clean)) \
                         .map(lambda x, y: (preprocess_image(x), preprocess_image(y))) \
                         .batch(batch_size)

test_ds = tf.data.Dataset.from_tensor_slices((test_noisy, test_clean)) \
                        .map(lambda x, y: (preprocess_image(x), preprocess_image(y))) \
                        .batch(batch_size)

# %%
def create_denoising_model(input_shape):
    model = models.Sequential([
        layers.Input(shape=input_shape),
        layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
        layers.MaxPooling2D((2, 2), padding='same'),
        layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
        layers.MaxPooling2D((2, 2), padding='same'),
        layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
        layers.UpSampling2D((2, 2)),
        layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
        layers.UpSampling2D((2, 2)),
        layers.Conv2D(3, (3, 3), activation='sigmoid', padding='same')
    ])
    return model

# Define input shape
input_shape = (128, 128, 3)

# Create the denoising model
model = create_denoising_model(input_shape)

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Print model summary
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 128, 128, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 64, 64, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 64, 64, 32)     │        18,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 32, 32, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d (UpSampling2D)    │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 64, 64, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_1 (UpSampling2D)  │ (None, 128, 128, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 128, 128, 3)    │         1,731 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 49,731 (194.26 KB)
#  Trainable params: 49,731 (194.26 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(train_ds, epochs=50, validation_data=test_ds)
# Out:
# Epoch 1/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 599ms/step - loss: 0.0476 - val_loss: 0.0349
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 661ms/step - loss: 0.0345 - val_loss: 0.0348
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 702ms/step - loss: 0.0316 - val_loss: 0.0316
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 645ms/step - loss: 0.0293 - val_loss: 0.0294
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 589ms/step - loss: 0.0281 - val_loss: 0.0281
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 614ms/step - loss: 0.0265 - val_loss: 0.0276
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 623ms/step - loss: 0.0261 - val_loss: 0.0283
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 592ms/step - loss: 0.0260 - val_loss: 0.0290
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 607ms/step - loss: 0.0261 - val_loss: 0.0293
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 701ms/step - loss: 0.0260 - val_loss: 0.0271
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 644ms/step - loss: 0.0252 - val_loss: 0.0279
# Epoch 12/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 620ms/step - loss: 0.0254 - val_loss: 0.0279
# Epoch 13/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 698ms/step - loss: 0.0253 - val_loss: 0.0272
# Epoch 14/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 705ms/step - loss: 0.0250 - val_loss: 0.0267
# Epoch 15/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 636ms/step - loss: 0.0247 - val_loss: 0.0269
# Epoch 16/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 604ms/step - loss: 0.0246 - val_loss: 0.0269
# Epoch 17/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 672ms/step - loss: 0.0246 - val_loss: 0.0268
# Epoch 18/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 605ms/step - loss: 0.0245 - val_loss: 0.0266
# Epoch 19/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 703ms/step - loss: 0.0243 - val_loss: 0.0263
# Epoch 20/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 650ms/step - loss: 0.0242 - val_loss: 0.0260
# Epoch 21/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 623ms/step - loss: 0.0240 - val_loss: 0.0260
# Epoch 22/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 588ms/step - loss: 0.0239 - val_loss: 0.0257
# Epoch 23/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 652ms/step - loss: 0.0238 - val_loss: 0.0256
# Epoch 24/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 586ms/step - loss: 0.0237 - val_loss: 0.0256
# Epoch 25/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 626ms/step - loss: 0.0236 - val_loss: 0.0254
# Epoch 26/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 709ms/step - loss: 0.0236 - val_loss: 0.0252
# Epoch 27/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 720ms/step - loss: 0.0234 - val_loss: 0.0252
# Epoch 28/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 678ms/step - loss: 0.0233 - val_loss: 0.0251
# Epoch 29/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 607ms/step - loss: 0.0232 - val_loss: 0.0250
# Epoch 30/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 599ms/step - loss: 0.0232 - val_loss: 0.0249
# Epoch 31/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 585ms/step - loss: 0.0231 - val_loss: 0.0249
# Epoch 32/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 602ms/step - loss: 0.0230 - val_loss: 0.0247
# Epoch 33/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 610ms/step - loss: 0.0229 - val_loss: 0.0247
# Epoch 34/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 586ms/step - loss: 0.0229 - val_loss: 0.0245
# Epoch 35/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 617ms/step - loss: 0.0228 - val_loss: 0.0245
# Epoch 36/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 643ms/step - loss: 0.0227 - val_loss: 0.0243
# Epoch 37/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 650ms/step - loss: 0.0226 - val_loss: 0.0243
# Epoch 38/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 628ms/step - loss: 0.0226 - val_loss: 0.0240
# Epoch 39/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 653ms/step - loss: 0.0224 - val_loss: 0.0241
# Epoch 40/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 623ms/step - loss: 0.0224 - val_loss: 0.0239
# Epoch 41/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 699ms/step - loss: 0.0223 - val_loss: 0.0239
# Epoch 42/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 701ms/step - loss: 0.0222 - val_loss: 0.0238
# Epoch 43/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 681ms/step - loss: 0.0222 - val_loss: 0.0236
# Epoch 44/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 661ms/step - loss: 0.0221 - val_loss: 0.0235
# Epoch 45/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 621ms/step - loss: 0.0220 - val_loss: 0.0234
# Epoch 46/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 677ms/step - loss: 0.0219 - val_loss: 0.0234
# Epoch 47/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 644ms/step - loss: 0.0219 - val_loss: 0.0234
# Epoch 48/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 645ms/step - loss: 0.0219 - val_loss: 0.0232
# Epoch 49/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 623ms/step - loss: 0.0218 - val_loss: 0.0231
# Epoch 50/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 604ms/step - loss: 0.0217 - val_loss: 0.0234

# %%
predicted_images = model.predict(test_ds)

psnr_values = [psnr(test_clean[i], predicted_images[i]) for i in range(len(test_clean))]
average_psnr = np.mean(psnr_values)
print(f'Average PSNR: {average_psnr}')
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step
# Average PSNR: 16.924197925848507

# %%
def plot_images(dataset, num_images=5):
    # Create an iterator for the dataset
    iterator = iter(dataset)
    
    # Get a batch of images and labels
    noisy_images, clean_images = next(iterator)
    
    # Plot the images
    plt.figure(figsize=(15, 7))
    for i in range(num_images):
        # Plot noisy image
        plt.subplot(2, num_images, i + 1)
        plt.imshow(noisy_images[i])
        plt.title('Noisy Image')
        plt.axis('off')
        
        # Plot clean image
        plt.subplot(2, num_images, num_images + i + 1)
        plt.imshow(clean_images[i])
        plt.title('Clean Image')
        plt.axis('off')
    
    plt.tight_layout()
    plt.show()

# %%
# Plot 7 images from the training dataset
plot_images(train_ds, num_images=5)

# Plot 7 images from the test dataset
plot_images(test_ds, num_images=5)
